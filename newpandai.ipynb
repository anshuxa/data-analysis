# %% [markdown]
# <a href="https://colab.research.google.com/github/anshuxa/data-analysis/blob/main/newpandai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandasai
# !pip install pandasai[google-ai]

# %%
import pandas as pd
from pandasai import Agent
import os
from pandasai.llm.google_gemini import GoogleGemini
from pandasai import SmartDataframe

# %%
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

# %%
data_dict = {
    "country": [
        "Delhi",
        "Mumbai",
        "Kolkata",
        "Chennai",
        "Jaipur",
        "Lucknow",
        "Pune",
        "Bengaluru",
        "Amritsar",
        "Agra",

    ],
    "annual tax collected": [
        19294482072,
        28916155672,
        24112550372,
        34358173362,
        17454337886,
        11812051350,
        16074023894,
        14909678554,
        43807565410,
        146318441864

    ],
    "happiness_index": [9.94, 7.16, 6.35, 8.07, 6.98, 6.1, 4.23, 8.22, 6.87, 3.36],}
df = pd.DataFrame(data_dict)
df.head()
# Out:
#    country  annual tax collected  happiness_index
# 0    Delhi           19294482072             9.94
# 1   Mumbai           28916155672             7.16
# 2  Kolkata           24112550372             6.35
# 3  Chennai           34358173362             8.07
# 4   Jaipur           17454337886             6.98

# %%
llm = GoogleGemini(api_key=GOOGLE_API_KEY)

# %%
pandas_ai = SmartDataframe(df, config={"llm": llm, "verbose": True})

# %%
pandas_ai.chat('Show a graph of happiness b country')
# Out:
# '/content/exports/charts/temp_chart.png'
